# %%
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\Shankar.K\\Downloads\\INDIAvi.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info() #concise summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33089 entries, 0 to 37330
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                33089 non-null  object
#  1   trending_date           33089 non-null  object
#  2   title                   33089 non-null  object
#  3   channel_title           33089 non-null  object
#  4   category_id             33089 non-null  int64
#  5   publish_time            33089 non-null  object
#  6   tags                    33089 non-null  object
#  7   views                   33089 non-null  int64
#  8   likes                   33089 non-null  int64
#  9   dislikes                33089 non-null  int64
#  10  comment_count           33089 non-null  int64
#  11  thumbnail_link          33089 non-null  object
#  12  comments_disabled       33089 non-null  bool
#  13  ratings_disabled        33089 non-null  bool
# ...

# %%
data.describe() #descriptive statistics
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  37352.000000  3.735200e+04  3.735200e+04  3.735200e+04    37352.00000
# mean      21.576596  1.060478e+06  2.708272e+04  1.665082e+03     2676.99743
# std        6.556593  3.184932e+06  9.714510e+04  1.607617e+04    14868.31713
# min        1.000000  4.024000e+03  0.000000e+00  0.000000e+00        0.00000
# 25%       23.000000  1.239155e+05  8.640000e+02  1.080000e+02       81.00000
# 50%       24.000000  3.045860e+05  3.069000e+03  3.260000e+02      329.00000
# 75%       24.000000  7.992912e+05  1.377425e+04  1.019250e+03     1285.00000
# max       43.000000  1.254322e+08  2.912710e+06  1.545017e+06   827755.00000

# %%
data = data.drop_duplicates()
data
# Out:
#           video_id trending_date  \
# 0      kzwfHumJyYc      17.14.11
# 1      zUZ1z7FwLc8      17.14.11
# 2      10L1hZ9qa58      17.14.11
# 3      N1vE8iiEg64      17.14.11
# 4      kJzGH0PVQHQ      17.14.11
# ...            ...           ...
# 37300  UPbi1oG5UPg      18.14.06
# 37301  3MTCSll3KGU      18.14.06
# 37302  TIE92mUvSsw      18.14.06
# 37319  1-0mS2ZBrQk      18.14.06
# 37330  K10YIAokjvE      18.14.06
#
#                                                    title       channel_title  \
# 0      Sharry Mann: Cute Munda ( Song Teaser) | Parmi...     Lokdhun Punjabi
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...             HJ NEWS
# 2      Stylish Star Allu Arjun @ ChaySam Wedding Rece...                TFPC
# 3                         Eruma Saani | Tamil vs English         Eruma Saani
# 4      why Samantha became EMOTIONAL @ Samantha naga ...          Filmylooks
# ...                                                  ...                 ...
# ...

# %%
data.isnull()
# Out:
#        video_id  trending_date  title  channel_title  category_id  \
# 0         False          False  False          False        False
# 1         False          False  False          False        False
# 2         False          False  False          False        False
# 3         False          False  False          False        False
# 4         False          False  False          False        False
# ...         ...            ...    ...            ...          ...
# 37300     False          False  False          False        False
# 37301     False          False  False          False        False
# 37302     False          False  False          False        False
# 37319     False          False  False          False        False
# 37330     False          False  False          False        False
#
#        publish_time   tags  views  likes  dislikes  comment_count  \
# 0             False  False  False  False     False          False
# ...

# %%
data.isnull().sum()
# Out:
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               527
# dtype: int64

# %%
data.notnull()
# Out:
#        video_id  trending_date  title  channel_title  category_id  \
# 0          True           True   True           True         True
# 1          True           True   True           True         True
# 2          True           True   True           True         True
# 3          True           True   True           True         True
# 4          True           True   True           True         True
# ...         ...            ...    ...            ...          ...
# 37300      True           True   True           True         True
# 37301      True           True   True           True         True
# 37302      True           True   True           True         True
# 37319      True           True   True           True         True
# 37330      True           True   True           True         True
#
#        publish_time  tags  views  likes  dislikes  comment_count  \
# 0              True  True   True   True      True           True
# ...

# %%
data.isnull().sum().sum()
# Out:
# 527

# %%
data2 = data.fillna(value=0)
data2
# Out:
#           video_id trending_date  \
# 0      kzwfHumJyYc      17.14.11
# 1      zUZ1z7FwLc8      17.14.11
# 2      10L1hZ9qa58      17.14.11
# 3      N1vE8iiEg64      17.14.11
# 4      kJzGH0PVQHQ      17.14.11
# ...            ...           ...
# 37300  UPbi1oG5UPg      18.14.06
# 37301  3MTCSll3KGU      18.14.06
# 37302  TIE92mUvSsw      18.14.06
# 37319  1-0mS2ZBrQk      18.14.06
# 37330  K10YIAokjvE      18.14.06
#
#                                                    title       channel_title  \
# 0      Sharry Mann: Cute Munda ( Song Teaser) | Parmi...     Lokdhun Punjabi
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...             HJ NEWS
# 2      Stylish Star Allu Arjun @ ChaySam Wedding Rece...                TFPC
# 3                         Eruma Saani | Tamil vs English         Eruma Saani
# 4      why Samantha became EMOTIONAL @ Samantha naga ...          Filmylooks
# ...                                                  ...                 ...
# ...

# %%
data2.isnull().sum().sum()
# Out:
# 0

# %%
data3 = data.fillna(method='pad')
data3
# Out:
# C:\Users\Shankar.K\AppData\Local\Temp\ipykernel_464\3463156805.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3 = data.fillna(method='pad')#second method (forward filling method)
#           video_id trending_date  \
# 0      kzwfHumJyYc      17.14.11
# 1      zUZ1z7FwLc8      17.14.11
# 2      10L1hZ9qa58      17.14.11
# 3      N1vE8iiEg64      17.14.11
# 4      kJzGH0PVQHQ      17.14.11
# ...            ...           ...
# 37300  UPbi1oG5UPg      18.14.06
# 37301  3MTCSll3KGU      18.14.06
# 37302  TIE92mUvSsw      18.14.06
# 37319  1-0mS2ZBrQk      18.14.06
# 37330  K10YIAokjvE      18.14.06
#
#                                                    title       channel_title  \
# 0      Sharry Mann: Cute Munda ( Song Teaser) | Parmi...     Lokdhun Punjabi
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...             HJ NEWS
# ...

# %%
#filling null values with the next value
data4=data.fillna(method='bfill')
data4
# Out:
# C:\Users\Shankar.K\AppData\Local\Temp\ipykernel_464\1502939909.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data4=data.fillna(method='bfill')
#           video_id trending_date  \
# 0      kzwfHumJyYc      17.14.11
# 1      zUZ1z7FwLc8      17.14.11
# 2      10L1hZ9qa58      17.14.11
# 3      N1vE8iiEg64      17.14.11
# 4      kJzGH0PVQHQ      17.14.11
# ...            ...           ...
# 37300  UPbi1oG5UPg      18.14.06
# 37301  3MTCSll3KGU      18.14.06
# 37302  TIE92mUvSsw      18.14.06
# 37319  1-0mS2ZBrQk      18.14.06
# 37330  K10YIAokjvE      18.14.06
#
#                                                    title       channel_title  \
# 0      Sharry Mann: Cute Munda ( Song Teaser) | Parmi...     Lokdhun Punjabi
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...             HJ NEWS
# 2      Stylish Star Allu Arjun @ ChaySam Wedding Rece...                TFPC
# ...

# %%
import numpy as np
from scipy import stats

# %%
#detect the outliers using IQR
data2.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
data2.drop(['video_id', 'trending_date', 'title', 'channel_title','publish_time', 'tags','thumbnail_link', 'comments_disabled', 'ratings_disabled',
       'video_error_or_removed', 'description'], axis=1, inplace=True)
data2.columns
# Out:
# Index(['category_id', 'views', 'likes', 'dislikes', 'comment_count'], dtype='object')

# %%
Q1=data2.quantile(0.25)
Q3=data2.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# category_id           1.0
# views            619303.0
# likes             11224.0
# dislikes            834.0
# comment_count      1097.0
# dtype: float64

# %%
data2=data2[~((data2< (Q1-1.5*IQR) ) | (data2>(Q3+1.5*IQR)) ) .any(axis=1)]
data2
# Out:
#        category_id   views  likes  dislikes  comment_count
# 1               25  590101    735       904              0
# 2               24  473988   2011       243            149
# 4               24  464015    492       293             66
# 8               24  118223    520        53             23
# 12              25  156085    716        53              0
# ...            ...     ...    ...       ...            ...
# 37291           24  277211    869       225             56
# 37295           23   29536   1559        64             94
# 37296           22  186197    855        86             25
# 37298           25  145452    627       100             34
# 37330           23  132055  11170       393           2107
#
# [20698 rows x 5 columns]

# %%
data2.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  20698.000000  2.069800e+04  20698.000000  20698.000000   20698.000000
# mean      23.935549  2.922204e+05   3251.538796    317.437579     344.873997
# std        0.825911  2.899499e+05   4794.185851    367.714377     471.985847
# min       22.000000  4.024000e+03      0.000000      0.000000       0.000000
# 25%       24.000000  9.444825e+04    483.000000     72.000000      43.000000
# 50%       24.000000  1.890815e+05   1330.500000    181.000000     154.000000
# 75%       24.000000  3.828452e+05   3752.000000    419.000000     443.000000
# max       25.000000  1.660490e+06  28823.000000   2183.000000    2814.000000
